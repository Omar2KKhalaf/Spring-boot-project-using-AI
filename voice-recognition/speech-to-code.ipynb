# %%
# !pip install openai==0.28
# !pip install pyaudio
# !pip install SpeechRecognition
# !pip install Pillow
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
openai_api_key = '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'

# %%
from PIL import Image, ImageTk
import tkinter as tk
import time
import pyaudio
import speech_recognition as sr
import openai
import os
import requests

# %%
## Functions to convert speech to text and get OpenAI response
# Define a function to convert speech to text
def convert_speech_to_text():
    # Initialize the recognizer
    recognizer = sr.Recognizer()
    
    # Capture audio from the microphone
    with sr.Microphone() as source:
        print("Ask me anything...")
        recognizer.adjust_for_ambient_noise(source)  # Adjust for ambient noise
        audio = recognizer.listen(source)
    
    # Recognize speech using Google Web Speech API
    try:
        print("Wait a minute, I am trying to analyze this new accent u just invented...")
        text = recognizer.recognize_google(audio)
        return text
    except sr.UnknownValueError:
        print("Could not understand audio")
    except sr.RequestError as e:
        print("Error fetching results; {0}".format(e))

def get_openai_response(prompt, openai_api_key):
    if openai_api_key is None:
        raise ValueError("OpenAI API key is not set in environment variables.")

    url = "https://api.openai.com/v1/chat/completions"

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {openai_api_key}"
    }

    data = {
        "model": "gpt-3.5-turbo",
        "messages": [
            {
                "role": "system",
                "content": "You are a helpful assistant."
            },
            {
                "role": "user",
                "content": prompt
            }
        ]
    }

    response = requests.post(url, headers=headers, json=data)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()['choices'][0]['message']['content']
    else:
        raise ValueError(f"Error: {response.status_code}, {response.text}")

# %%
while True:
    # Convert speech to text
    text = convert_speech_to_text()
    if text:
        # Get OpenAI response
        response = get_openai_response(text, openai_api_key)
        break
# Out:
# Speak something...
# Transcribing speech...

# %% [markdown]
# ![Zakir Naik: "Brother asked a very good question" and "Hope that answers the question"](https://i.makeagif.com/media/10-22-2022/F2Vr5a.gif)

# %%
print("Here is your code: ", response)
# Out:
# Good morning! I'd be happy to help you with the weather. Could you please tell me your location or the city you are interested in knowing the weather for today?
